# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path

# %%
os.chdir("/Users/kyunhee/Projects/life_insurance/life_insurance")

from engine.mortality import param_mort_k2013

param_mort_k2013("M")
# Out:
# array([ 2.671548e+00, -1.724800e-01,  1.485000e-03])

# %%
base = Path("/Users/kyunhee/Projects/life_insurance/life_insurance")

# %%
mp_2024 = pd.read_csv(base / "model_point" / "model_points_2024.csv")

# %%
mp_2024_sample = mp_2024.head(1)
mp_2024_sample
# Out:
#     mp_id  issue_year  issue_age gender  sum_assured  premium_pay_term  \
# 0  240001        2024         54      F    100000000                10
#
#   payment_type
# 0         frac
